# %%
# %pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1 (from deep-translator)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\mia.jensen\anaconda3\envs\python_3_11_11\lib\site-packages (from deep-translator) (2.32.3)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mia.jensen\anaconda3\envs\python_3_11_11\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mia.jensen\anaconda3\envs\python_3_11_11\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mia.jensen\anaconda3\envs\python_3_11_11\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mia.jensen\anaconda3\envs\python_3_11_11\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mia.jensen\anaconda3\envs\python_3_11_11\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2025.1.31)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, deep-translator
# Successfully installed beautifulsoup4-4.13.4 deep-translator-1.11.4 soupsieve-2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.set_option('display.max_columns', None)

from deep_translator import GoogleTranslator

# %%
path = kagglehub.dataset_download("pkdarabi/classification-of-travel-purpose")
df = pd.read_csv(path + "\\train_data.csv")
df.head()
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
#                    Created CancelTime        DepartureTime    BillID  \
# 0  2022-10-23 09:38:49.110        NaN  2022-11-02 23:59:00  39710203
# 1  2022-08-15 14:51:43.160        NaN  2022-08-18 04:15:00  38689463
# 2  2022-09-20 17:25:27.250        NaN  2022-09-21 11:00:00  39245173
# 3  2022-06-25 11:32:53.980        NaN  2022-06-26 08:30:00  37957585
# 4  2022-06-01 11:30:53.633        NaN  2022-06-02 23:00:00  37584530
#
#     TicketID  ReserveStatus    UserID   Male      Price  CouponDiscount  \
# 0  1091777.0              5  122885.0   True  6600000.0         34425.0
# 1  1070902.0              5  876925.0   True  9500000.0             0.0
# 2  7624237.0              3  916640.0  False  2000000.0             0.0
# 3  2867547.0              2       NaN  False    40000.0             0.0
# 4  7212559.0              3       NaN   True  1130000.0             0.0
#
#     From                  To  Domestic              VehicleType VehicleClass  \
# 0  گرگان               تهران         1                      NaN        False
# 1   مشهد               تهران         1                      NaN        False
# 2  شیراز               اهواز         1                  VIP 2+1         True
# 3  تبریز                جلفا         1          3 ستاره اتوبوسي          NaN
# 4  تهران  نجف آباد (اصفهان )         1  اسکانیا تک صندلی ۳۱نفره         True
#
#   TripReason Vehicle  Cancel HashPassportNumber_p  \
# 0       Work   Plane       0                  NaN
# 1        Int   Plane       0                  NaN
# 2       Work     Bus       0                  NaN
# 3        Int   Train       0                  NaN
# 4        Int     Bus       0                  NaN
#
#                                            HashEmail   BuyerMobile  \
# 0  66c7f29e3b92f3b77e20830ac29e7758037a53d2238a5b...  764974891906
# 1  b24634843858a4175d03422aa9e7211ec3b9f3ce4c481c...   27479149496
# 2                                                NaN  323657282999
# 3                                                NaN  169459057632
# 4                                                NaN  408595008421
#
#    NationalCode
# 0     477368495
# 1      15987669
# 2     667640412
# 3     392476186
# 4      79497837

# %% [markdown]
# Column definitions:
# * Created: The timestamp indicates the ticket registration time.
# * CancelTime: The timestamp when the passenger canceled the ticket, if applicable.
# * DepartureTime: The scheduled departure time for the trip.
# * BillID: The unique identifier for the purchase transaction.
# * TicketID: The unique identifier for the ticket.
# * ReserveStatus: The payment status of the customer.
# * UserID: The unique identifier for the user.
# * Male: Indicates whether the ticket belongs to a male passenger or not.
# * Price: The ticket price without any discounts.
# * CouponDiscount: The discount applied by the passenger on the ticket.
# * From: The origin of the trip.
# * To: The destination of the trip.
# * Domestic: Indicates whether the trip is domestic or international.
# * VehicleType: Specifies details about the mode of transportation.
# * VehicleClass: Indicates whether the vehicle is first class or not.
# * Vehicle: Specifies the type of vehicle.
# * Cancel: Indicates whether the ticket has been canceled or not.
# * HashPassportNumber_p: Hashed version of the passport number.
# * HashEmail: Hashed version of the email address.
# * BuyerMobile : Hashed version of the buyer's mobile number.
# * NationalCode : Hashed version of the national identification number.
# * TripReason : The reason for the trip.

# %%
df["FromTranslated"] = df["From"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
df["ToTranslated"] = df["To"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
df["VehicleTypeTranslated"] = df["VehicleType"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
df.head()
# Out:
# ---------------------------------------------------------------------------
# TranslationNotFound                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df["FromTranslated"] = df["From"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
#       2 df["ToTranslated"] = df["To"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
#       3 df["VehicleTypeTranslated"] = df["VehicleType"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
#
# File c:\Users\mia.jensen\Anaconda3\envs\Python_3_11_11\Lib\site-packages\pandas\core\series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# File c:\Users\mia.jensen\Anaconda3\envs\Python_3_11_11\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\mia.jensen\Anaconda3\envs\Python_3_11_11\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[55], line 1, in <lambda>(text)
# ----> 1 df["FromTranslated"] = df["From"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
#       2 df["ToTranslated"] = df["To"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
#       3 df["VehicleTypeTranslated"] = df["VehicleType"].map(lambda text: GoogleTranslator(source='ar', target='en').translate(text))
#
# File c:\Users\mia.jensen\Anaconda3\envs\Python_3_11_11\Lib\site-packages\deep_translator\google.py:84, in GoogleTranslator.translate(self, text, **kwargs)
#      82     element = soup.find(self._element_tag, self._alt_element_query)
#      83     if not element:
# ---> 84         raise TranslationNotFound(text)
#      85 if element.get_text(strip=True) == text.strip():
#      86     to_translate_alpha = "".join(
#      87         ch for ch in text.strip() if ch.isalnum()
#      88     )
#
# TranslationNotFound: ایرانشهر --> No translation was found using the current translator. Try another translator?
